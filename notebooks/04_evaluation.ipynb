# %% [markdown]
# # 04 — Evaluation & Submission
#
# ## 1. Evaluation Metrics
# - MAE
# - RMSE
# - R²
#
# ## 2. Model Comparison
# - Compare all models
#
# ## 3. Error Analysis
# - Identify failure cases
#
# ## 4. Final Model Selection
#
# ## 5. Generate Submission
# - Match sample_submission format

# %%
from pathlib import Path
import sys
import subprocess

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT != PROJECT_ROOT.parent and not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.append(str(PROJECT_ROOT))

import joblib
pkg = joblib.load(PROJECT_ROOT / 'outputs' / 'models' / 'model_package.joblib')
pkg['metrics']

# %%
# Generate submission via the prediction script
cmd = [sys.executable, '-m', 'src.models.predict']
subprocess.run(cmd, cwd=str(PROJECT_ROOT), check=True)

# %% [markdown]
# Submission will be written to `outputs/submissions/submission.csv`.
