# %% [markdown]
# # 03 — Modeling
#
# ## 1. Problem Definition
# - Forecast Revenue (and COGS)
#
# ## 2. Model Selection
# - Linear Regression
# - Random Forest
# - XGBoost / LightGBM
#
# ## 3. Training Strategy
# - Time-series cross-validation
#
# ## 4. Model Training
# - Train multiple models
# - Save models
#
# ## 5. Feature Importance
# - Plot and analyze

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT != PROJECT_ROOT.parent and not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.append(str(PROJECT_ROOT))

from src.models.train import train

model_path = train(
    raw_dir=PROJECT_ROOT / 'data' / 'raw',
    model_out=PROJECT_ROOT / 'outputs' / 'models' / 'model_package.joblib',
    val_days=365,
    lags=[1, 7, 14, 28, 56, 365],
    windows=[7, 14, 28],
    random_state=42,
)
model_path

# %%
import joblib
pkg = joblib.load(model_path)
pkg['metrics']

# %% [markdown]
# ## Next experiments (optional)
# - Try different lag sets (e.g., add 90-day, 180-day)
# - Try alternative models (e.g., LinearRegression, RandomForest)
# - Add exogenous signals if test-period values exist (promotions/web_traffic/inventory in 2023+)
